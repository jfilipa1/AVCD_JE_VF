# %% [markdown]
# ## Final project in Analysis and Visualization of Complex Agro-Environmental Data

# %% [markdown]
# Create a wordcloud for our report cover:

# %%
# Libraries
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create a list of word
text=("Citrus Olive Fruit Nuts Cereals Dried Pulses Fodder Plants Flowers Ornamental Potatoes Sugarbeets Temporary Grasses Grazings Vineyards")

# Create the wordcloud object
wordcloud = WordCloud(width=480, height=480, margin=0, background_color="white").generate(text)

# Display the generated image
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %%
# Libraries
import pandas as pd

# read the data (on the web)
data = pd.read_csv('3_perm_crops.csv')

# Check the first 2 rows
data.head(2)
# Out:
#                                 Nuts_region_perm     NutsID       region_name  \
# 0  111160101_Aboim das Choças_Citrus plantations  111160101  Aboim das Choças
# 1   111160101_Aboim das Choças_Olive plantations  111160101  Aboim das Choças
#
#             Perm_crop  Area_1989  Area_1999  Area_2009  Area_2019
# 0  Citrus plantations          0          0          0          0
# 1   Olive plantations          0          0          0          0

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the data from a CSV file (assuming the data is stored in a file called "data.csv")
data = pd.read_csv('3_perm_crops.csv')

# Convert 'region_name' column to category data type
data['region_name'] = data['region_name'].astype('category')

# Set the figure size
plt.figure(figsize=(10, 10))

# Scatterplot
plt.scatter(
    x=data['Perm_crop'],
    y=data['Area_1989'],
    c=data['region_name'].cat.codes,
    cmap="Accent",
    alpha=0.6,
    edgecolors="white",
    linewidth=2
)

# Set the x-axis and y-axis limits
plt.ylim(0, 12000)  # Adjust the limits as per your data

# Add titles (main and on axis)
plt.xlabel("Perm_crop")
plt.ylabel("Area_1989")
plt.title("Scatterplot")
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the data from a CSV file (assuming the data is stored in a file called "data.csv")
data = pd.read_csv('3_perm_crops.csv')

# Convert 'region_name' column to category data type
data['region_name'] = data['region_name'].astype('category')

# Set the figure size
plt.figure(figsize=(10, 10))

# Scatterplot
plt.scatter(
    x=data['Perm_crop'],
    y=data['Area_1999'],
    c=data['region_name'].cat.codes,
    cmap="Accent",
    alpha=0.6,
    edgecolors="white",
    linewidth=2
)

# Set the x-axis and y-axis limits
plt.ylim(0, 12000)  # Adjust the limits as per your data

# Add titles (main and on axis)
plt.xlabel("Perm_crop")
plt.ylabel("Area_1999")
plt.title("Scatterplot")
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the data from a CSV file (assuming the data is stored in a file called "data.csv")
data = pd.read_csv('3_perm_crops.csv')

# Convert 'region_name' column to category data type
data['region_name'] = data['region_name'].astype('category')

# Set the figure size
plt.figure(figsize=(10, 10))

# Scatterplot
plt.scatter(
    x=data['Perm_crop'],
    y=data['Area_2009'],
    c=data['region_name'].cat.codes,
    cmap="Accent",
    alpha=0.6,
    edgecolors="white",
    linewidth=2
)

# Set the x-axis and y-axis limits
plt.ylim(0, 12000)  # Adjust the limits as per your data

# Add titles (main and on axis)
plt.xlabel("Perm_crop")
plt.ylabel("Area_2009")
plt.title("Scatterplot")
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Load the data from a CSV file (assuming the data is stored in a file called "data.csv")
data = pd.read_csv('3_perm_crops.csv')

# Convert 'region_name' column to category data type
data['region_name'] = data['region_name'].astype('category')

# Set the figure size
plt.figure(figsize=(10, 10))

# Scatterplot
plt.scatter(
    x=data['Perm_crop'],
    y=data['Area_2019'],
    c=data['region_name'].cat.codes,
    cmap="Accent",
    alpha=0.6,
    edgecolors="white",
    linewidth=2
)

# Set the x-axis and y-axis limits
plt.ylim(0, 12000)  # Adjust the limits as per your data

# Add titles (main and on axis)
plt.xlabel("Perm_crop")
plt.ylabel("Area_2019")
plt.title("Scatterplot")
plt.xticks(rotation=90)

# Display the plot
plt.show()
