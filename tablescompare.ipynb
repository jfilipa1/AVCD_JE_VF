# %% [markdown]
# # Comparation of our database and the shapefile database

# %%
import csv

# Function to compare two fields and check if they match
def compare_fields(field1, field2):
    # Perform the comparison logic here
    # Return True if fields match, False otherwise
    return field1 == field2

# Paths to the CSV files
csv_file1 = 'ffeguesias.csv'
csv_file2 = '3_temp_crops.csv'

# Fields to compare
field1_name = 'Freguesia'
field2_name = 'region_name'

# Open the CSV files and compare the fields
with open(csv_file1, 'r', encoding='utf-8') as file1, open(csv_file2, 'r', encoding='utf-8') as file2:
    reader1 = csv.DictReader(file1)
    reader2 = csv.DictReader(file2)

    for row1 in reader1:
        for row2 in reader2:
            if compare_fields(row1[field1_name], row2[field2_name]):
                # Match found
                print(f"Match found: {row1[field1_name]} in first table and {row2[field2_name]} in second table.")
                # You can perform further actions with the matching rows here

        # Reset the reader2 back to the beginning for each row in reader1
        file2.seek(0)
# Out:
# Match found: Sagres in first table and Sagres in second table.
# Match found: Sagres in first table and Sagres in second table.
# Match found: Sagres in first table and Sagres in second table.
# Match found: Sagres in first table and Sagres in second table.
# Match found: Sagres in first table and Sagres in second table.
# Match found: Sagres in first table and Sagres in second table.
# Match found: Sagres in first table and Sagres in second table.
# Match found: Sagres in first table and Sagres in second table.
# Match found: Sagres in first table and Sagres in second table.
# Match found: Sagres in first table and Sagres in second table.
# Match found: União das freguesias de Faro (Sé e São Pedro) in first table and União das freguesias de Faro (Sé e São Pedro) in second table.
# Match found: União das freguesias de Faro (Sé e São Pedro) in first table and União das freguesias de Faro (Sé e São Pedro) in second table.
# ...
