# %% [markdown]
# # Analysis of trends in temporary crops

# %% [markdown]
# ## All freguesias

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from a CSV file
data = pd.read_csv('3_temp_crops.csv')

# Step 2: Calculate the sum of the area for each region
sum_area = data.groupby('region_name')[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Step 3: Create the line plot
years = ['1989', '1999', '2009', '2019']
regions = sum_area.index

for region in regions:
    plt.plot(years, sum_area.loc[region], label=region)

plt.xlabel('Years')
plt.ylabel('Total Area')
plt.title('Area variation of Temporary Crops in Each Region Over Time')
#plt.legend()
plt.show()

# %% [markdown]
# ### Add trendlines to all freguesias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from a CSV file
data = pd.read_csv('3_temp_crops.csv')

# Step 2: Calculate the sum of the area for each region
sum_area = data.groupby('region_name')[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Step 3: Create the line plot with trend lines and separate based on slope
years = ['1989', '1999', '2009', '2019']
regions = sum_area.index

positive_slope_regions = []
negative_slope_regions = []
in_between_regions = []

for region in regions:
    # Calculate the trend line using linear regression
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    coeffs = np.polyfit(x, y, 1)
    trend_line = np.poly1d(coeffs)

    # Calculate the slope
    slope = coeffs[0]

    # Plot the original data
    plt.plot(years, y, label=region)

    # Plot the trend line
    plt.plot(years, trend_line(x), linestyle='dashed')

    # Separate based on slope
    if slope > 1.5:
        positive_slope_regions.append(region)
    elif slope < -1.5:
        negative_slope_regions.append(region)
    else:
        in_between_regions.append(region)

plt.xlabel('Years')
plt.ylabel('Total Area')
plt.title('Trend line variation of Temporary Crops in Each Region Over Time')
#plt.legend()
plt.show()

print("Regions with positive slope (> 1.5):")
print(positive_slope_regions)
print("\nRegions with negative slope (< -1.5):")
print(negative_slope_regions)
print("\nRegions in between the slopes:")
print(in_between_regions)
# Out:
# Regions with positive slope (> 1.5):
# ['Achada', 'Achadinha', 'Agualva', 'Ajuda da Bretanha', 'Alcochete', 'Alcântara', 'Algarvia', 'Alhos Vedros', 'Almeirim', 'Almendra', 'Altares', 'Angra (São Pedro)', 'Arrifes', 'Arrouquelas', 'Asseiceira', 'Aveiras de Cima', 'Azambuja', 'Azinhaga', 'Balazar', 'Barcelinhos', 'Benavente', 'Benfica do Ribatejo', 'Biscoitos', 'Boavista dos Pinheiros', 'Brotas', 'Bunheiro', 'Cabo da Praia', 'Cabouco', 'Calhetas', 'Cambres', 'Campanhã', 'Candelária', 'Caniçal', 'Capelas', 'Caranguejeira', 'Carregueira', 'Castelo Novo', 'Cercal', 'Colos', 'Comporta', 'Covoada', 'Câmara de Lobos', 'Doze Ribeiras', 'Enxames', 'Ereira', 'Faial da Terra', 'Fajozes', 'Fajã de Cima', 'Fazenda', 'Fazendas de Almeirim', 'Fenais da Ajuda', 'Feteiras', 'Flamengos', 'Fonte do Bastardo', 'Fontinhas', 'Fradelos', 'Furnas', 'Galveias', 'Ginetes', 'Golegã', 'Gouvinhas', 'Guilhabreu', 'Gândaras', 'Ilha', 'Jardim da Serra', 'Labruge', 'Lagoa (Nossa Senhora do Rosário)', 'Lagoa (Santa Cruz)', 'Lajedo', 'Lajes', 'Lajes das Flores', 'Laundos', 'Lomba da Maia', 'Longueira/Almograve', 'Lumiar', 'Luzianes-Gare', 'Macieira da Maia', 'Maia', 'Manhente', 'Meia Via', 'Meãs do Campo', 'Misericórdia', 'Moinhos da Gândara', 'Monsanto', 'Montalvo', 'Montalvão', 'Montenegro', 'Nordeste', 'Nossa Senhora de Fátima', 'Odivelas', 'Olhalvo', 'Orjais', 'Ota', 'Oura', 'Paialvo', 'Pico da Pedra', 'Pilar da Bretanha', 'Ponta Delgada (São Sebastião)', 'Ponta Garça', 'Porto Judeu', 'Porto Martins', 'Porto Santo', 'Posto Santo', 'Povoação', 'Praia da Vitória (Santa Cruz)', 'Póvoa da Isenta', 'Quatro Ribeiras', 'Rabo de Peixe', 'Ramalde', 'Raminho', 'Rates', 'Relva', 'Remelhe', 'Remédios', 'Riachos', 'Ribamondego', 'Ribeira Grande (Conceição)', 'Ribeira Grande (Matriz)', 'Ribeira Seca', 'Ribeira das Tainhas', 'Ribeirinha', 'Riodades', 'Rogil', 'Rosto do Cão (Livramento)', 'Rosto do Cão (São Roque)', 'Sagres', 'Salga', 'Santa Bárbara', 'Santa Clara', 'Santa Cruz da Graciosa', 'Santa Margarida da Coutada', 'Santiago Maior', 'Santo António', 'Santo António da Serra', 'Santo António de Nordestinho', 'Santo Espírito', 'Serreta', 'Sesimbra (Santiago)', 'São Bartolomeu de Regatos', 'São Brás', 'São Jacinto', 'São João dos Caldeireiros', 'São Luís', 'São Martinho da Gândara', 'São Mateus da Calheta', 'São Pedro da Cadeira', 'São Pedro de Nordestinho', 'São Pedro de Tomar', 'São Vicente Ferreira', 'Teixeira', 'Terra Chã', 'Tramagal', 'Ulme', 'União das freguesias da Chamusca e Pinheiro Grande', 'União das freguesias de A dos Cunhados e Maceira', 'União das freguesias de Abrunheira, Verride e Vila Nova da Barca', 'União das freguesias de Alcórrego e Maranhão', 'União das freguesias de Alvega e Concavada', 'União das freguesias de Bacelo e Senhora da Saúde', 'União das freguesias de Bagunte, Ferreiró, Outeiro Maior e Parada', 'União das freguesias de Bensafrim e Barão de São João', 'União das freguesias de Brogueira, Parceiros de Igreja e Alcorochel', 'União das freguesias de Carregado e Cadafais', 'União das freguesias de Coimbra (Sé Nova, Santa Cruz, Almedina e São Bartolomeu)', 'União das freguesias de Escudeiros e Penso (Santo Estêvão e São Vicente)', 'União das freguesias de Gaio-Rosário e Sarilhos Pequenos', 'União das freguesias de Glória e Vera Cruz', 'União das freguesias de Lagoa e Carvoeiro', 'União das freguesias de Madalena e Beselga', 'União das freguesias de Malagueira e Horta das Figueiras', 'União das freguesias de Marmeleira e Assentiz', 'União das freguesias de Marrazes e Barosa', 'União das freguesias de Maxial e Monte Redondo', 'União das freguesias de Melo e Nabais', 'União das freguesias de Monfortinho e Salvaterra do Extremo', 'União das freguesias de Monte Redondo e Carreira', 'União das freguesias de Parceiros e Azoia', 'União das freguesias de Rio Mau e Arcos', 'União das freguesias de Salvaterra de Magos e Foros de Salvaterra', 'União das freguesias de Setúbal (São Julião, Nossa Senhora da Anunciada e Santa Maria da Graça)', 'União das freguesias de Silva e Águas Vivas', 'União ...
#
# Regions with negative slope (< -1.5):
# ['A dos Francos', 'A dos Negros', 'Abade de Neiva', 'Abadim', 'Abambres', 'Abaças', 'Abedim', 'Abela', 'Abitureiras', 'Abiul', 'Aboim da Nóbrega e Gondomar', 'Aboim das Choças', 'Aborim', 'Abragão', 'Abraveses', 'Abreiro', 'Abrunhosa-a-Velha', 'Abrã', 'Achadas da Cruz', 'Adaúfe', 'Adães', 'Adão', 'Afife', 'Agilde', 'Agregação das freguesias Sul de Pinhel', 'Agrela', 'Agrochão', 'Aguada de Cima', 'Agualonga', 'Aguda', 'Aguiar', 'Aguiar de Sousa', 'Aguieiras', 'Aguiã', 'Airães', 'Airó', 'Aião', 'Alagoa', 'Albergaria-a-Velha e Valmaior', 'Albufeira e Olhos de Água', 'Alburitel', 'Alcabideche', 'Alcafache', 'Alcaide', 'Alcains', 'Alcanede', 'Alcanhões', 'Alcaravela', 'Alcaria', 'Alcaria Ruiva', 'Alcobertas', 'Alcoentre', 'Alcofra', 'Alcáçovas', 'Aldeia Nova', 'Aldeia Velha', 'Aldeia Viçosa', 'Aldeia da Mata', 'Aldeia da Ponte', 'Aldeia das Dez', 'Aldeia de Santa Margarida', 'Aldeia de São Francisco de Assis', 'Aldeia do Bispo', 'Aldeia dos Fernandes', 'Aldeias', 'Aldreu', 'Aldão', 'Alegrete', 'Alfaiates', 'Alfaião', 'Alfarela de Jales', 'Alfarelos', 'Alfeizerão', 'Alfena', 'Alferce', 'Alfragide', 'Alfândega da Fé', 'Algeriz', 'Algodres', 'Alguber', 'Algueirão-Mem Martins', 'Alhadas', 'Alijó', 'Aljezur', 'Aljubarrota', 'Almaceda', 'Almagreira', 'Almalaguês', 'Almancil', 'Almeida', 'Almofala', 'Almoster', 'Alpalhão', 'Alpedrinha', 'Alpendorada, Várzea e Torrão', 'Alpiarça', 'Alqueidão', 'Alqueidão da Serra', 'Alquerubim', 'Alte', 'Alter do Chão', 'Alto do Palurdo', 'Alturas do Barroso e Cerdedo', 'Alvadia', 'Alvaiázere', 'Alvalade', 'Alvaredo', 'Alvarenga', 'Alvares', 'Alvarães', 'Alvelos', 'Alvendre', 'Alverca da Beira/Bouça Cova', 'Alvite', 'Alvites', 'Alvito', 'Alvoco da Serra', 'Alvoco das Várzeas', 'Alvor', 'Alvorge', 'Alvorninha', 'Alvão', 'Amareleja', 'Ameixial', 'Amendoeira', 'Amiais de Baixo', 'Amonde', 'Amor', 'Amora', 'Amoreira', 'Amêndoa', 'Anais', 'Andrães', 'Anelhe', 'Angeja', 'Angra (Nossa Senhora da Conceição)', 'Angra (Santa Luzia)', 'Angra (Sé)', 'Anha', 'Anobra', 'Ansiães', 'Ansião', 'Antas', 'Ançã', 'Aradas', 'Aranhas', 'Arazede', 'Arca e Ponte de Lima', 'Arcas', 'Arco da Calheta', 'Arco de São Jorge', 'Arcos', 'Arcozelo', 'Arcozelo das Maias', 'Arcozelos', 'Ardegão, Freixo e Mato', 'Ardãos e Bobadela', 'Arega', 'Areias', 'Areosa', 'Arganil', 'Argela', 'Argoncilhe', 'Argozelo', 'Armamar', 'Armação de Pêra', 'Armil', 'Arnas', 'Arneiro das Milhariças', 'Arnóia', 'Arrabal', 'Arraiolos', 'Arranhó', 'Arrifana', 'Arroios', 'Arruda dos Vinhos', 'Arões', 'Arões (Santa Cristina)', 'Arões (São Romão)', 'Assentiz', 'Associação de freguesias do Vale do Neiva', 'Assumar', 'Assunção', 'Assunção, Ajuda, Salvador e Santo Ildefonso', 'Astromil', 'Atalaia', 'Atei', 'Atiães', 'Atouguia', 'Atouguia da Baleia', 'Avanca', 'Aveiras de Baixo', 'Avelal', 'Avelar', 'Aveleda', 'Aveloso', 'Avelãs da Ribeira', 'Avelãs de Cima', 'Aves', 'Avessadas e Rosém', 'Avintes', 'Avis', 'Avô', 'Avões', 'Azias', 'Azinhal', 'Azinheira dos Barros e São Mamede do Sádão', 'Azinhoso', 'Azurara', 'Azurém', 'Açoreira', 'Babe', 'Baguim do Monte (Rio Tinto)', 'Bairro', 'Bajouca', 'Balança', 'Baldos', 'Baleizão', 'Baltar', 'Balugães', 'Bandeiras', 'Banho e Carvalhosa', 'Baraçal', 'Barbeita', 'Barcarena', 'Barco', 'Barcouço', 'Barqueiros', 'Barrancos', 'Barreira', 'Barreiros', 'Barroca', 'Barrosa', 'Barroças e Taias', 'Barrô', 'Barão de São Miguel', 'Basto', 'Basto (São Clemente)', 'Batalha', 'Baçal', 'Beco', 'Beijós', 'Beiral do Lima', 'Beire', 'Beirã', 'Bela', 'Belver', 'Bem Viver', 'Bemposta', 'Bencatel', 'Bendada', 'Benedita', 'Benespera', 'Benfeita', 'Benlhevai', 'Benquerença', 'Benquerenças', 'Beringel', 'Bertiandos', 'Beselga', 'Beça', 'Bico', 'Bidoeira de Cima', 'Bilhó', 'Biscainho', 'Bismula', 'Boa Ventura', 'Boalhosa', 'Bobadela', 'Bodiosa', 'Boelhe', 'Bogas de Cima', 'Boidobra', 'Boivães', 'Boivão', 'Boliqueime', 'Bom Sucesso', 'Borba (Matriz)', 'Borba de Montanha', 'Bordeira', 'Bordonhos', 'Bornes de Aguiar', 'Boticas e Granja', 'Bouro (Santa Maria)', ' ...
#
# Regions in between the slopes:
# ['Adorigo', 'Ajuda', 'Alcongosta', 'Altura', 'Alvações do Corgo', 'Areeiro', 'Avelãs de Caminho', 'Avenidas Novas', 'Beato', 'Belém', 'Benfica', 'Bonfim', 'Borba (São Bartolomeu)', 'Campo de Ourique', 'Campolide', 'Casal de Cambra', 'Caveira', 'Celeirós', 'Cidadelhe', 'Coimbrão', 'Covas do Douro', 'Cumieira', 'Curral das Freiras', 'Delães', 'Desejosa', 'Estrela', 'Fernão Ferro', 'Ferreiros de Avões', 'Fontelas', 'Funchal (Santa Luzia)', 'Funchal (São Pedro)', 'Funchal (Sé)', 'Imaculado Coração de Maria', 'Lomba de São Pedro', 'Madalena do Mar', 'Maiorca', 'Marvila', 'Medrões', 'Moitas Venda', 'Nagozelo do Douro', 'Olhão', 'Olivais', 'Paramos', 'Parque das Nações', 'Paul do Mar', 'Penajóia', 'Penha de França', 'Pinhão', 'Porto Salvo', 'Porto de Mós - São João Baptista e São Pedro', 'Prainha', 'Quinta do Conde', 'Rio de Mouro', 'Roliça', 'Sabrosa', 'Sabroso de Aguiar', 'Salão', 'Samodães', 'Sande', 'Seixo de Ansiães', 'Soutelo do Douro', 'São Domingos de Benfica', 'São Gonçalo', 'São João', 'São Paio de Oleiros', 'São Roque do Pico', 'Tancos', 'Telhado', 'União das freguesias de Agualva e Mira-Sintra', 'União das freguesias de Aldoar, Foz do Douro e Nevogilde', 'União das freguesias de Algés, Linda-a-Velha e Cruz Quebrada-Dafundo', 'União das freguesias de Braga (São José de São Lázaro e São João do Souto)', 'União das freguesias de Castedo e Cotas', 'União das freguesias de Cedofeita, Santo Ildefonso, Sé, Miragaia, São Nicolau e Vitória', 'União das freguesias de Laranjeiro e Feijó', 'União das freguesias de Lobrigos (São Miguel e São João Baptista) e Sanhoane', 'União das freguesias de Lordelo do Ouro e Massarelos', 'União das freguesias de Massamá e Monte Abraão', 'União das freguesias de Moscavide e Portela', 'União das freguesias de Parada do Bispo e Valdigem', 'União das freguesias de Pontinha e Famões', 'União das freguesias de Provesende, Gouvães do Douro e São Cristóvão do Douro', 'União das freguesias de Póvoa de Rio de Moinhos e Cafede', 'União das freguesias de Póvoa de Santa Iria e Forte da Casa', 'União das freguesias de Sacavém e Prior Velho', 'União das freguesias de Santa Clara-a-Nova e Gomes Aires', 'União das freguesias de Serra e Junceira', 'União das freguesias de Vale de Mendiz, Casal de Loivos e Vilarinho de Cotas', 'União das freguesias de Vilarouco e Pereiros', 'União das freguesias do Cacém e São Marcos', 'Usseira', 'Valdujo', 'Vale da Mula', 'Valença do Douro', 'Vilarinho de São Romão', 'Água de Alto', 'Água de Pena']

# %% [markdown]
# ### Freguesias by slope class, positive, negative and flat

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from a CSV file
data = pd.read_csv('3_temp_crops.csv')

# Step 2: Calculate the sum of the area for each region
sum_area = data.groupby('region_name')[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Step 3: Create the line plots for each class
years = ['1989', '1999', '2009', '2019']
regions = sum_area.index

positive_slope_regions = []
negative_slope_regions = []
in_between_regions = []

for region in regions:
    # Calculate the trend line using linear regression
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    coeffs = np.polyfit(x, y, 1)
    trend_line = np.poly1d(coeffs)

    # Calculate the slope
    slope = coeffs[0]

    if slope > 1.5:
        positive_slope_regions.append(region)
    elif slope < -1.5:
        negative_slope_regions.append(region)
    else:
        in_between_regions.append(region)

# Plot the regions with positive slope
plt.figure()
for region in positive_slope_regions:
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    plt.plot(years, y, label=region)

plt.xlabel('Years')
plt.ylabel('Total Area')
plt.title('Regions with Positive Slope (> 1.5) of Temporary Crops')
#plt.legend()
plt.savefig('images/freg_slope_positive_temp.png')
plt.show()

# Plot the regions with negative slope
plt.figure()
for region in negative_slope_regions:
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    plt.plot(years, y, label=region)

plt.xlabel('Years')
plt.ylabel('Total Area')
plt.title('Regions with Negative Slope (< -1.5) of Temporary Crops')
#plt.legend()
# Save the last image to the "images" folder
plt.savefig('images/freg_negative_neutral_temp.png')
plt.show()

# Plot the regions in between the slopes
plt.figure()
for region in in_between_regions:
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    plt.plot(years, y, label=region)

plt.xlabel('Years')
plt.ylabel('Total Area')
plt.title('Regions In Between the Slopes of Temporary Crops')
#plt.legend()
plt.savefig('images/freg_slope_neutral_temp.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from a CSV file
data = pd.read_csv('3_temp_crops.csv')

# Step 2: Calculate the sum of the area for each region
sum_area = data.groupby('region_name')[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Step 3: Create the line plots for each class
years = ['1989', '1999', '2009', '2019']
regions = sum_area.index

positive_slope_regions = []
negative_slope_regions = []
in_between_regions = []

for region in regions:
    # Calculate the trend line using linear regression
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    coeffs = np.polyfit(x, y, 1)
    trend_line = np.poly1d(coeffs)

    # Calculate the slope
    slope = coeffs[0]

    if slope > 1.5:
        positive_slope_regions.append(region)
    elif slope < -1.5:
        negative_slope_regions.append(region)
    else:
        in_between_regions.append(region)

# Create a single figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot the regions with positive slope
axes[0].set_title('Freguesias with Positive Slope (> 1.5) of Temporary Crops')
for region in positive_slope_regions:
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    axes[0].plot(years, y, label=region)
axes[0].set_xlabel('Years')
axes[0].set_ylabel('Total Area')
#axes[0].legend()

# Plot the regions with negative slope
axes[1].set_title('Freguesias with Negative Slope (< -1.5) of Temporary Crops')
for region in negative_slope_regions:
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    axes[1].plot(years, y, label=region)
axes[1].set_xlabel('Years')
axes[1].set_ylabel('Total Area')
#axes[1].legend()

# Plot the regions in between the slopes
axes[2].set_title('Freguesias In Between the Slopes of Temporary Crops')
for region in in_between_regions:
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    axes[2].plot(years, y, label=region)
axes[2].set_xlabel('Years')
axes[2].set_ylabel('Total Area')
#axes[2].legend()

# Adjust the layout and save the image
plt.tight_layout()
plt.savefig('images/combined_slopes_temporary.png')
plt.show()

# %% [markdown]
# ### Chart of the class of most positive and negative growth, by temporary crop type

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the data from a CSV file
data = pd.read_csv('3_temp_crops.csv')

# Step 2: Calculate the sum of the area for each region and crop
sum_area = data.groupby(['region_name', 'Temp_crop'])[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Calculate the slope and variation for each region and crop
region_crop_stats = []
for (region, crop), region_crop_data in sum_area.groupby(['region_name', 'Temp_crop']):
    years = ['1989', '1999', '2009', '2019']
    x = np.arange(len(years))
    y = region_crop_data.values.squeeze()
    coeffs = np.polyfit(x, y, 1)
    slope = coeffs[0]
    variation = np.abs(np.diff(y)).mean()
    region_crop_stats.append((region, crop, slope, variation))

# Separate region-crop combinations into positive slopes and negative slopes
positive_slopes = [(region, crop, slope, variation) for region, crop, slope, variation in region_crop_stats if slope > 0]
negative_slopes = [(region, crop, slope, variation) for region, crop, slope, variation in region_crop_stats if slope < 0]

# Sort the positive and negative slopes based on slope value in descending order
sorted_positive_slopes = sorted(positive_slopes, key=lambda x: x[2], reverse=True)
sorted_negative_slopes = sorted(negative_slopes, key=lambda x: abs(x[2]), reverse=True)


# Create a table using pandas.DataFrame.style for positive slopes
positive_slopes_df = pd.DataFrame(sorted_positive_slopes, columns=['Region Name', 'Crop Name', 'Slope', 'Variation'])
top_10_positive_slopes = positive_slopes_df.head(10)
positive_styled_table = top_10_positive_slopes.style.set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'center')]}]
).set_caption('Top 10 Region-Crop Combinations with Biggest Positive Slopes')

# Convert styled table to DataFrame for positive slopes
positive_table_df = positive_styled_table.data

# Create a table using pandas.DataFrame.style for negative slopes
negative_slopes_df = pd.DataFrame(sorted_negative_slopes, columns=['Region Name', 'Crop Name', 'Slope', 'Variation'])
top_10_negative_slopes = negative_slopes_df.head(10)
negative_styled_table = top_10_negative_slopes.style.set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'center')]}]
).set_caption('Top 10 Region-Crop Combinations with Biggest Negative Slopes')

# Convert styled table to DataFrame for negative slopes
negative_table_df = negative_styled_table.data


# Create a graph showing region-crop combinations and their variations for positive slopes
plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_positive_slopes, x='Region Name', y='Variation', hue='Crop Name')
plt.xlabel('Region Name')
plt.ylabel('Variation')
plt.title('Region-Crop Combinations with the Biggest Variations (Positive Slopes)')
plt.xticks(rotation=50, fontsize=8, ha='right', va='top')
plt.legend(title='Crop Name')


# Save the last image to the "images" folder
plt.savefig('images/biggest_win_slope_temp.png')
plt.show()

# Create a graph showing region-crop combinations and their variations for negative slopes
plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_negative_slopes, x='Region Name', y='Variation', hue='Crop Name')
plt.xlabel('Region Name')
plt.ylabel('Variation')
plt.title('Region-Crop Combinations with the Biggest Variations (Negative Slopes)')

plt.xticks(rotation=50, fontsize=8, ha='right', va='top')
plt.legend(title='Crop Name')


# Save the last image to the "images" folder
plt.savefig('images/biggest_loss_slope_temp.png')
plt.show()

# %% [markdown]
# ### Table of most positive and negative slope freguesias of temp crops

# %%
from prettytable import PrettyTable

# Create a table using PrettyTable for positive slopes
positive_table = PrettyTable()
positive_table.field_names = ['Region Name', 'Crop Name', 'Slope', 'Variation(ha)']
positive_table.align = 'l'  # Align columns to the left
for region_crop in sorted_positive_slopes[:10]:
    positive_table.add_row([region_crop[0], region_crop[1], f"{region_crop[2]:.2f}", f"{region_crop[3]:.2f}"])

print('Top 10 Region-Crop Combinations with Biggest Positive Slopes:')
print(positive_table)
print()

# Create a table using PrettyTable for negative slopes
negative_table = PrettyTable()
negative_table.field_names = ['Region Name', 'Crop Name', 'Slope', 'Variation(ha)']
negative_table.align = 'l'  # Align columns to the left
for region_crop in sorted_negative_slopes[:10]:
    negative_table.add_row([region_crop[0], region_crop[1], f"{region_crop[2]:.2f}", f"{region_crop[3]:.2f}"])

print('Top 10 Region-Crop Combinations with Biggest Negative Slopes:')
print(negative_table)
print()
# Out:
# Top 10 Region-Crop Combinations with Biggest Positive Slopes:
# +------------------------------------------------------------------------------------+--------------------------------+---------+---------------+
# | Region Name                                                                        | Crop Name                      | Slope   | Variation(ha) |
# +------------------------------------------------------------------------------------+--------------------------------+---------+---------------+
# | Pavia                                                                              | Fodder plants                  | 1570.40 | 2823.67       |
# | União das freguesias de Castro Verde e Casével                                     | Temporary grasses and grazings | 1108.00 | 1232.67       |
# | Vila Franca de Xira                                                                | Cereals                        | 894.70  | 938.67        |
# | Monforte                                                                           | Temporary grasses and grazings | 891.80  | 1033.33       |
# | Cercal                                                                             | Fodder plants                  | 849.30  | 873.67        |
# | União das freguesias de Aljustrel e Rio de Moinhos                                 | Temporary grasses and grazings | 844.80  | 1225.33       |
# | União das freguesias de Campo e Campinho                                           | Fodder plants                  | 783.90  | 839.00        |
# | União das freguesias de Moura (Santo Agostinho e São João Baptista) e Santo Amador | Fodder plants                  | 721.80  | 1077.33       |
# | Valada                                                                             | Fresh vegetables               | 655.40  | 587.00        |
# | União das freguesias de Panoias e Conceição                                        | Fodder plants                  | 652.70  | 694.00        |
# +------------------------------------------------------------------------------------+--------------------------------+---------+---------------+
#
# Top 10 Region-Crop Combinations with Biggest Negative Slopes:
# +----------------------------------------------------------------+-----------+----------+---------------+
# | Region Name                                                    | Crop Name | Slope    | Variation(ha) |
# +----------------------------------------------------------------+-----------+----------+---------------+
# | União das freguesias de Serpa (Salvador e Santa Maria)         | Cereals   | -3079.70 | 3126.67       |
# | União das freguesias de Ferreira do Alentejo e Canhestros      | Cereals   | -2700.60 | 2357.67       |
# | União das freguesias de São Manços e São Vicente do Pigeiro    | Cereals   | -2645.40 | 2806.00       |
# | União das freguesias de Castro Verde e Casével                 | Cereals   | -2111.00 | 2066.33       |
# | União das freguesias de Aljustrel e Rio de Moinhos             | Cereals   | -2057.50 | 2026.67       |
# | Vimieiro                                                       | Cereals   | -1680.20 | 1753.33       |
# | Pavia                                                          | Cereals   | -1647.80 | 1657.67       |
# | Assunção                                                       | Cereals   | -1532.20 | 1441.67       |
# | Monforte                                                       | Cereals   | -1530.60 | 1490.00       |
# | União das freguesias de Vila Nova de São Bento e Vale de Vargo | Cereals   | -1526.60 | 1614.00       |
# +----------------------------------------------------------------+-----------+----------+---------------+

# %% [markdown]
# ### Number and percentage of each class of slope of temporary crops

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from a CSV file
data = pd.read_csv('3_temp_crops.csv')

# Step 2: Calculate the sum of the area for each region
sum_area = data.groupby('region_name')[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Step 3: Categorize the regions based on slope
years = ['1989', '1999', '2009', '2019']
regions = sum_area.index

positive_slope_regions = []
negative_slope_regions = []
in_between_regions = []

for region in regions:
    # Calculate the trend line using linear regression
    x = range(len(years))
    y = sum_area.loc[region].values
    coeffs = np.polyfit(x, y, 1)
    slope = coeffs[0]

    if slope > 1.5:
        positive_slope_regions.append(region)
    elif slope < -1.5:
        negative_slope_regions.append(region)
    else:
        in_between_regions.append(region)

# Count the number of regions in each category
positive_count = len(positive_slope_regions)
negative_count = len(negative_slope_regions)
in_between_count = len(in_between_regions)

# Create a pie chart
categories = ['Positive Slope', 'Negative Slope', 'In Between']
counts = [positive_count, negative_count, in_between_count]

plt.pie(counts, labels=categories, autopct='%1.1f%%')

# Add count numbers below the percentages
plt.gca().set_aspect('equal')  # Ensure pie is drawn as a circle
plt.text(0.5, 0.3, f'{positive_count}', fontsize=9)
plt.text(-0.7, -0.25, f'{negative_count}', fontsize=9)
plt.text(0.5, -0.25, f'{in_between_count}', fontsize=9)

plt.title('Distribution of Slope Categories of Temporary Crops')
plt.tight_layout()

# Save the last image to the "images" folder
plt.savefig('images/slope_categories_percentage_temp.png')

plt.show()
