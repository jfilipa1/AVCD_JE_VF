# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from a CSV file
data = pd.read_csv('3_perm_crops.csv')

# Step 2: Calculate the sum of the area for each region
sum_area = data.groupby('region_name')[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Step 3: Create the line plot
years = ['1989', '1999', '2009', '2019']
regions = sum_area.index

for region in regions:
    plt.plot(years, sum_area.loc[region], label=region)

plt.xlabel('Years')
plt.ylabel('Total Area')
plt.title('Total Area of Crops in Each Region Over Time')
#plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from a CSV file
data = pd.read_csv('3_perm_crops.csv')

# Step 2: Calculate the sum of the area for each region
sum_area = data.groupby('region_name')[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Step 3: Create the line plot with trend lines and separate based on slope
years = ['1989', '1999', '2009', '2019']
regions = sum_area.index

positive_slope_regions = []
negative_slope_regions = []
in_between_regions = []

for region in regions:
    # Calculate the trend line using linear regression
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    coeffs = np.polyfit(x, y, 1)
    trend_line = np.poly1d(coeffs)

    # Calculate the slope
    slope = coeffs[0]

    # Plot the original data
    plt.plot(years, y, label=region)

    # Plot the trend line
    plt.plot(years, trend_line(x), linestyle='dashed')

    # Separate based on slope
    if slope > 1.5:
        positive_slope_regions.append(region)
    elif slope < -1.5:
        negative_slope_regions.append(region)
    else:
        in_between_regions.append(region)

plt.xlabel('Years')
plt.ylabel('Total Area')
plt.title('Total Area of Crops in Each Region Over Time')
#plt.legend()
plt.show()

print("Regions with positive slope (> 1.5):")
print(positive_slope_regions)
print("\nRegions with negative slope (< -1.5):")
print(negative_slope_regions)
print("\nRegions in between the slopes:")
print(in_between_regions)
# Out:
# Regions with positive slope (> 1.5):
# ['Abambres', 'Abaças', 'Abela', 'Abraveses', 'Abreiro', 'Abrunhosa-a-Velha', 'Agilde', 'Agregação das freguesias Sul de Pinhel', 'Aguieiras', 'Airães', 'Aião', 'Alcafache', 'Alcaria Ruiva', 'Alcofra', 'Alcongosta', 'Alcântara', 'Aldeia Nova', 'Aldeia Velha', 'Aldeia das Dez', 'Aldeia do Bispo', 'Alfaiates', 'Alfaião', 'Alfarela de Jales', 'Algeriz', 'Almaceda', 'Almofala', 'Alte', 'Alto do Palurdo', 'Altura', 'Alvalade', 'Alvaredo', 'Alvarenga', 'Alverca da Beira/Bouça Cova', 'Alvite', 'Alvites', 'Alvito', 'Alvorge', 'Alvão', 'Amareleja', 'Ameixial', 'Amendoeira', 'Amêndoa', 'Angra (Nossa Senhora da Conceição)', 'Angra (São Pedro)', 'Arcas', 'Arcos', 'Arcozelo', 'Ardãos e Bobadela', 'Areias', 'Argozelo', 'Arnas', 'Arraiolos', 'Arrifana', 'Arrouquelas', 'Assunção, Ajuda, Salvador e Santo Ildefonso', 'Atei', 'Avelal', 'Aveleda', 'Avelãs da Ribeira', 'Avis', 'Avô', 'Avões', 'Azinhaga', 'Azinhal', 'Azinheira dos Barros e São Mamede do Sádão', 'Azinhoso', 'Babe', 'Baldos', 'Baleizão', 'Bandeiras', 'Baraçal', 'Barbeita', 'Barreiros', 'Barroças e Taias', 'Baçal', 'Beijós', 'Benavente', 'Benlhevai', 'Beça', 'Biscainho', 'Boavista dos Pinheiros', 'Bobadela', 'Bogas de Cima', 'Boivão', 'Bordeira', 'Bordonhos', 'Bornes de Aguiar', 'Bouça', 'Bouçoães', 'Branca', 'Brinches', 'Britiande', 'Brunhoso', 'Bruçó', 'Buarcos', 'Budens', 'Cabanelas', 'Cabaços', 'Cabeça Gorda', 'Cabeço de Vide', 'Cabeção', 'Cabrela', 'Cabril', 'Cachopo', 'Caia, São Pedro e Alcáçova', 'Calvelo', 'Cambeses', 'Cambres', 'Campanário', 'Campeã', 'Canaveses', 'Canaviais', 'Candedo', 'Candelária', 'Canha', 'Canidelo', 'Caniçal', 'Cano', 'Capelins (Santo António)', 'Capelo', 'Capinha', 'Carapito', 'Caravelas', 'Carragosa', 'Carrapatas', 'Carrazedo', 'Carrazedo de Montenegro e Curros', 'Carregal', 'Carvalhais', 'Carção', 'Casa Branca', 'Casal Vasco', 'Casal de Cinza', 'Casas do Soeiro', 'Castainço', 'Castedo', 'Casteleiro', 'Castelejo', 'Castelo Novo', 'Castelo Rodrigo', 'Castelo de Penalva', 'Castro Vicente', 'Castro de Avelãs', 'Cavadoude', 'Cavernães', 'Caíde de Rei', 'Cedovim', 'Cedães', 'Celas', 'Celeirós', 'Cercal', 'Cervos', 'Chacim', 'Chavães', 'Chosendo', 'Chã', 'Chãs', 'Ciladas', 'Cimbres', 'Cimo de Vila da Castanheira', 'Cobro', 'Coelhoso', 'Colos', 'Comenda', 'Comporta', 'Correlhã', 'Cortiçada', 'Cortiços', 'Corujas', 'Corval', 'Coucieiro', 'Couto de Esteves', 'Couço', 'Covas', 'Covas do Douro', 'Cuba', 'Cumieira', 'Curral das Freiras', 'Cárquere', 'Cótimos', 'Dominguizo', 'Donai', 'Dornelas', 'Edral', 'Edrosa', 'Eirado', 'Eja', 'Encosta do Sol', 'Enxames', 'Ermesinde', 'Ermidas-Sado', 'Ervedal', 'Ervedosa', 'Ervidel', 'Ervões', 'Escalhão', 'Esmolfe', 'Espinhosela', 'Espírito Santo', 'Estorãos', 'Facha', 'Fajã de Baixo', 'Fajão-Vidual', 'Faro do Alentejo', 'Favaios', 'Fernão Ferro', 'Ferreira', 'Ferreira de Aves', 'Ferreiras', 'Ferreiros de Avões', 'Ferreiros de Tendais', 'Fervença', 'Feteira', 'Figueira dos Cavaleiros', 'Figueira e Barros', 'Fiães', 'Folgosa', 'Folgosinho', 'Forninhos', 'Fornos', 'Fornos de Maceira Dão', 'Foros de Arrão', 'Foros de Vale de Figueira', 'Fradizela', 'Fragosela', 'França', 'Freixiel', 'Freixo de Numão', 'Fridão', 'Friões', 'Fóios', 'Gaeiras', 'Gafanha da Nazaré', 'Galveias', 'Ganfei', 'Gemeses', 'Genísio', 'Geraz do Minho', 'Germil', 'Gimonde', 'Giões', 'Glória', 'Gondesende', 'Gonçalo Bocas', 'Gostei', 'Gouveia', 'Gouvinhas', 'Gralhas', 'Granja', 'Granjal', 'Grijó', 'Grijó de Parada', 'Grilo', 'Guilhabreu', 'Guilheiro', 'Gândaras', 'Igrejinha', 'Ilha', 'Jardim da Serra', 'Jou', 'Lagares e Figueira', 'Lagoa', 'Lamas', 'Lamas de Orelhão', 'Lamosa', 'Landeira', 'Lara', 'Larinho', 'Lavacolhos', 'Lavegadas', 'Lazarim', 'Lebução, Fiães e Nozelos', 'Leomil', 'Loivos do Monte', 'Longa', 'Longos Vales', 'Longroiva', 'Longueira/Almograve', 'Lordosa', 'Lorvão', 'Louriçal do Campo', 'Lusinde', 'Luz', 'Luzianes-Gare', 'Macedo do Mato', 'Macinhata do Vouga', 'Madalena do Mar', 'Mairos', 'Malhadas', 'Manteigas (Santa Maria)', 'Martim Longo', 'Mar ...
#
# Regions with negative slope (< -1.5):
# ['A dos Francos', 'A dos Negros', 'Abade de Neiva', 'Abadim', 'Abitureiras', 'Abiul', 'Aboim da Nóbrega e Gondomar', 'Aboim das Choças', 'Aborim', 'Abragão', 'Abrã', 'Achada', 'Adaúfe', 'Adorigo', 'Adães', 'Adão', 'Afife', 'Agrela', 'Aguada de Cima', 'Agualva', 'Aguda', 'Aguiar', 'Airó', 'Alagoa', 'Albergaria-a-Velha e Valmaior', 'Albufeira e Olhos de Água', 'Alburitel', 'Alcaide', 'Alcains', 'Alcanede', 'Alcanhões', 'Alcaravela', 'Alcaria', 'Alcobertas', 'Alcochete', 'Alcoentre', 'Alcáçovas', 'Aldeia Viçosa', 'Aldeia da Mata', 'Aldeia da Ponte', 'Aldeia de Santa Margarida', 'Aldeias', 'Aldreu', 'Aldão', 'Alegrete', 'Alfarelos', 'Alfeizerão', 'Alfena', 'Alferce', 'Alfândega da Fé', 'Algodres', 'Alguber', 'Alhadas', 'Alhos Vedros', 'Alijó', 'Aljezur', 'Aljubarrota', 'Almagreira', 'Almalaguês', 'Almancil', 'Almeida', 'Almeirim', 'Almendra', 'Almoster', 'Alpalhão', 'Alpedrinha', 'Alpendorada, Várzea e Torrão', 'Alpiarça', 'Alqueidão', 'Alqueidão da Serra', 'Alquerubim', 'Altares', 'Alter do Chão', 'Alvaiázere', 'Alvares', 'Alvarães', 'Alvações do Corgo', 'Alvelos', 'Alvoco da Serra', 'Alvoco das Várzeas', 'Alvor', 'Alvorninha', 'Amiais de Baixo', 'Amonde', 'Amor', 'Amora', 'Amoreira', 'Anais', 'Andrães', 'Anelhe', 'Angeja', 'Angra (Santa Luzia)', 'Angra (Sé)', 'Anha', 'Anobra', 'Ansiães', 'Ansião', 'Antas', 'Ançã', 'Aranhas', 'Arazede', 'Arca e Ponte de Lima', 'Arco de São Jorge', 'Arcozelos', 'Arega', 'Arganil', 'Argela', 'Argoncilhe', 'Armação de Pêra', 'Armil', 'Arneiro das Milhariças', 'Arnóia', 'Arrabal', 'Arranhó', 'Arrifes', 'Arroios', 'Arruda dos Vinhos', 'Arões', 'Arões (Santa Cristina)', 'Arões (São Romão)', 'Asseiceira', 'Assentiz', 'Associação de freguesias do Vale do Neiva', 'Assumar', 'Assunção', 'Astromil', 'Atalaia', 'Atiães', 'Atouguia', 'Atouguia da Baleia', 'Avanca', 'Aveiras de Baixo', 'Aveiras de Cima', 'Avelar', 'Aveloso', 'Avelãs de Caminho', 'Avelãs de Cima', 'Aves', 'Avessadas e Rosém', 'Avintes', 'Azambuja', 'Azias', 'Azurém', 'Açoreira', 'Baguim do Monte (Rio Tinto)', 'Bajouca', 'Balança', 'Balazar', 'Baltar', 'Balugães', 'Barcarena', 'Barcelinhos', 'Barco', 'Barcouço', 'Barqueiros', 'Barrancos', 'Barreira', 'Barroca', 'Barrosa', 'Barrô', 'Barão de São Miguel', 'Basto', 'Basto (São Clemente)', 'Batalha', 'Beco', 'Beirã', 'Bela', 'Belver', 'Bem Viver', 'Bemposta', 'Bencatel', 'Bendada', 'Benedita', 'Benfeita', 'Benfica do Ribatejo', 'Benquerença', 'Benquerenças', 'Beringel', 'Bico', 'Bilhó', 'Biscoitos', 'Bismula', 'Boa Ventura', 'Boelhe', 'Boidobra', 'Boivães', 'Boliqueime', 'Borba (Matriz)', 'Borba (São Bartolomeu)', 'Borba de Montanha', 'Boticas e Granja', 'Bouro (Santa Maria)', 'Bouro (Santa Marta)', 'Bragado', 'Brandara', 'Britelo', 'Brito', 'Brotas', 'Brufe', 'Bucelas', 'Bucos', 'Bugalhos', 'Bunheiro', 'Bustelo', 'Bárrio', 'Cabana Maior', 'Cabanas de Viriato', 'Cabaços e Fojo Lobal', 'Cabeceiras de Basto', 'Cabeça Santa', 'Cabeçudo', 'Cabo da Praia', 'Cabouco', 'Cabração e Moreira do Lima', 'Cabreiro', 'Cacia', 'Cadima', 'Caires', 'Calde', 'Caldelas', 'Calheiros', 'Calheta', 'Calheta de Nesquim', 'Calhetas', 'Calvaria de Cima', 'Calvão', 'Camacha', 'Cambas', 'Campo', 'Campo de Besteiros', 'Canas de Santa Maria', 'Canas de Senhorim', 'Candemil', 'Candosa', 'Canedo', 'Canelas', 'Canhas', 'Caniço', 'Cantelães', 'Capelas', 'Capeludos', 'Caranguejeira', 'Carapelhos', 'Carapeços', 'Carapinha', 'Carapinheira', 'Cardosas', 'Caria', 'Carnide', 'Carnota', 'Carrapichana', 'Carrazeda de Ansiães', 'Carregosa', 'Carregueira', 'Carregueiros', 'Carriço', 'Carvalhal', 'Carvalhal Benfeito', 'Carvalhas', 'Carvalheira', 'Carvalho', 'Carvalhosa', 'Carviçais', 'Carvoeira', 'Casal Comba', 'Castanheiro do Sul', 'Castelo', 'Castelo Bom', 'Castelo Branco', 'Castelo Melhor', 'Castelo do Neiva', 'Castelões', 'Castro Daire', 'Castro Marim', 'Cativelos', 'Cavez', 'Caxarias', 'Cedros', 'Ceira', 'Cela', 'Celavisa', 'Cendufe', 'Cepelos', 'Cercosa', 'Cerdal', 'Cerdeira', 'Cerejais', 'Cernache', 'Cervães', 'Cesar', 'Cete', 'Chafé',  ...
#
# Regions in between the slopes:
# ['Abedim', 'Achadas da Cruz', 'Achadinha', 'Agrochão', 'Agualonga', 'Aguiar de Sousa', 'Aguiã', 'Ajuda', 'Ajuda da Bretanha', 'Alcabideche', 'Aldeia de São Francisco de Assis', 'Aldeia dos Fernandes', 'Alfragide', 'Algarvia', 'Algueirão-Mem Martins', 'Alturas do Barroso e Cerdedo', 'Alvadia', 'Alvendre', 'Aradas', 'Arco da Calheta', 'Arcozelo das Maias', 'Ardegão, Freixo e Mato', 'Areeiro', 'Areosa', 'Armamar', 'Avenidas Novas', 'Azurara', 'Bairro', 'Banho e Carvalhosa', 'Beato', 'Beiral do Lima', 'Beire', 'Belém', 'Benespera', 'Benfica', 'Bertiandos', 'Beselga', 'Bidoeira de Cima', 'Boalhosa', 'Bodiosa', 'Bom Sucesso', 'Bonfim', 'Braga (São Vicente)', 'Braga (São Vítor)', 'Brasfemes', 'Bravães', 'Bárrio e Cepões', 'Cabeça Boa', 'Campanhã', 'Campelo', 'Campia', 'Campo de Ourique', 'Campo do Gerês', 'Campolide', 'Candoso (São Martinho)', 'Capela', 'Cardigos', 'Carreço', 'Carvoeiro', 'Casal de Cambra', 'Castanheira', 'Castêlo da Maia', 'Caveira', 'Codessoso, Curros e Fiães do Tâmega', 'Cogula', 'Cornes', 'Corroios', 'Cortegaça', 'Corvo', 'Costa da Caparica', 'Cousso', 'Covas do Barroso', 'Covelo do Gerês', 'Cuide de Vila Verde', 'Cujó', 'Câmara de Lobos', 'Delães', 'Dornelas do Zêzere', 'Doze Ribeiras', 'Erada', 'Ereira', 'Ericeira', 'Escapães', 'Escariz', 'Esgueira', 'Esmoriz', 'Espadanedo', 'Estrela', 'Fajozes', 'Fajã Grande', 'Fajãzinha', 'Falagueira-Venda Nova', 'Feitosa', 'Ferral', 'Ferreiros', 'Ferrel', 'Figueira de Lorvão', 'Figueiredo de Alva', 'Figueiró da Granja', 'Fonte Arcada', 'Fontoura', 'Fornelo do Monte', 'Foz do Arelho', 'Freixiosa', 'Friande', 'Friestas', 'Funchal (Sé)', 'Gafanha da Boa Hora', 'Gafanha da Encarnação', 'Gafanha do Carmo', 'Gaula', 'Gave', 'Gemieira', 'Gião', 'Gosende', 'Guarda', 'Guardizela', 'Gême', 'Irivo', 'Joane', 'João Antão', 'Labruja', 'Labrujó, Rendufe e Vilar do Monte', 'Lajedo', 'Lanhas', 'Loivo', 'Lombo', 'Loriga', 'Lufrei', 'Lumiar', 'Maceda', 'Macieira de Sarnes', 'Malcata', 'Manhouce', 'Marvila', 'Maçal do Chão', 'Mentrestido', 'Merufe', 'Meãs do Campo', 'Milheirós de Poiares', 'Mina de Água', 'Misericórdia', 'Moinhos da Gândara', 'Mundão', 'Nadadouro', 'Nogueira da Regedoura', 'Norte Grande (Neves)', 'Odeceixe', 'Oleiros', 'Olivais', 'Oliveira (Santa Maria)', 'Oliveira (São Mateus)', 'Oliveira do Douro', 'Oliveirinha', 'Padim da Graça', 'Paramos', 'Parque das Nações', 'Paço de Sousa', 'Paços', 'Pedro Miguel', 'Pedrouços', 'Pega', 'Pena Verde', 'Penamaior', 'Penha de França', 'Peniche', 'Pepim', 'Pessegueiro', 'Pessegueiro do Vouga', 'Pilar da Bretanha', 'Pitões das Junias', 'Ponta Delgada (São Sebastião)', 'Porto Judeu', 'Porto Salvo', 'Posto Santo', 'Praia da Vitória (Santa Cruz)', 'Praia de Mira', 'Praia do Almoxarife', 'Queiriga', 'Queiriz', 'Quinta do Conde', 'Quintas de São Bartolomeu', 'Ramalde', 'Ramela', 'Rapoula do Côa', 'Reboleiro', 'Refontoura', 'Rego', 'Reigoso', 'Resende', 'Revinhade', 'Riba de Ave', 'Riba de Âncora', 'Ribeira de Fráguas', 'Ribeiradio', 'Ribeiros', 'Ribeirão', 'Rio Meão', 'Rio de Mouro', 'Romarigães', 'Rosto do Cão (Livramento)', 'Sabroso de Aguiar', 'Salto', 'Salão', 'Sampriz', 'Samões', 'Sanguedo', 'Santa Clara', 'Santa Margarida da Coutada', 'Santa Maria de Lamas', 'Santana da Azinha', 'Santiago da Guarda', 'Santo António de Nordestinho', 'Santo Varão', 'Sapiãos', 'Sarzedo', 'Sazes da Beira', 'Sazes do Lorvão', 'Seara', 'Sebolido', 'Seixo da Beira', 'Serreta', 'Sesimbra (Santiago)', 'Silvalde', 'Sobreira', 'Sobreposta', 'Sul', 'São Bernardo', 'São Domingos de Benfica', 'São Domingos de Rana', 'São Félix', 'São Félix da Marinha', 'São Gião', 'São Jacinto', 'São Jorge da Beira', 'São João da Fresta', 'São João da Madeira', 'São João da Serra', 'São Miguel de Poiares', 'São Miguel do Mato', 'São Paio de Oleiros', 'São Pedro de France', 'São Pedro de Nordestinho', 'São Vicente Ferreira', 'Tabua', 'Tangil', 'Torre do Pinhão', 'Tourém', 'Travancinha', 'Tábua', 'Ucha', 'União das freguesias das Eiras, São Julião de Montenegro e Cela', 'União das freguesia ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from a CSV file
data = pd.read_csv('3_perm_crops.csv')

# Step 2: Calculate the sum of the area for each region
sum_area = data.groupby('region_name')[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Step 3: Create the line plots for each class
years = ['1989', '1999', '2009', '2019']
regions = sum_area.index

positive_slope_regions = []
negative_slope_regions = []
in_between_regions = []

for region in regions:
    # Calculate the trend line using linear regression
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    coeffs = np.polyfit(x, y, 1)
    trend_line = np.poly1d(coeffs)

    # Calculate the slope
    slope = coeffs[0]

    if slope > 1.5:
        positive_slope_regions.append(region)
    elif slope < -1.5:
        negative_slope_regions.append(region)
    else:
        in_between_regions.append(region)

# Plot the regions with positive slope
plt.figure()
for region in positive_slope_regions:
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    plt.plot(years, y, label=region)

plt.xlabel('Years')
plt.ylabel('Total Area')
plt.title('Regions with Positive Slope (> 1.5)')
#plt.legend()
plt.show()

# Plot the regions with negative slope
plt.figure()
for region in negative_slope_regions:
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    plt.plot(years, y, label=region)

plt.xlabel('Years')
plt.ylabel('Total Area')
plt.title('Regions with Negative Slope (< -1.5)')
#plt.legend()
plt.show()

# Plot the regions in between the slopes
plt.figure()
for region in in_between_regions:
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    plt.plot(years, y, label=region)

plt.xlabel('Years')
plt.ylabel('Total Area')
plt.title('Regions In Between the Slopes')
#plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from a CSV file
data = pd.read_csv('3_perm_crops.csv')

# Step 2: Calculate the sum of the area for each region
sum_area = data.groupby('region_name')[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Step 3: Create the line plots for each class
years = ['1989', '1999', '2009', '2019']
regions = sum_area.index

# Calculate the slope and variation for each region
region_stats = []
for region in regions:
    x = np.arange(len(years))
    y = sum_area.loc[region].values
    coeffs = np.polyfit(x, y, 1)
    trend_line = np.poly1d(coeffs)
    slope = coeffs[0]
    variation = np.abs(np.diff(y)).mean()
    crop_name = data[data['region_name'] == region]['Perm_crop'].iloc[0]
    region_stats.append((region, slope, variation, crop_name))

# Sort the regions based on variation in descending order
sorted_regions = sorted(region_stats, key=lambda x: x[2], reverse=True)

# Display the top 10 regions with the fastest changes in variation
print('Top 10 Regions with Fastest Changes in Variation:')
print('----------------------------------------------')
print('Region Name\t\tSlope\t\tVariation\tCrop Name')
print('----------------------------------------------')
for region in sorted_regions[:10]:
    print(f"{region[0]}\t\t{region[1]:.2f}\t\t{region[2]:.2f}\t\t{region[3]}")
print()

# Display the top 10 regions with the slowest changes in variation
print('Top 10 Regions with Slowest Changes in Variation:')
print('----------------------------------------------')
print('Region Name\t\tSlope\t\tVariation\tCrop Name')
print('----------------------------------------------')
for region in sorted_regions[-10:]:
    print(f"{region[0]}\t\t{region[1]:.2f}\t\t{region[2]:.2f}\t\t{region[3]}")
# Out:
# Top 10 Regions with Fastest Changes in Variation:
# ----------------------------------------------
# Region Name		Slope		Variation	Crop Name
# ----------------------------------------------
# União das freguesias de Alcácer do Sal (Santa Maria do Castelo e Santiago) e Santa Susana		4831.40		4180.33		Citrus plantations
# União das freguesias de Ferreira do Alentejo e Canhestros		2662.60		2522.33		Citrus plantations
# Comporta		1864.40		2068.33		Citrus plantations
# Baleizão		2160.80		1980.67		Citrus plantations
# União das freguesias de São Miguel do Pinheiro, São Pedro de Solis e São Sebastião dos Carros		1475.30		1901.67		Citrus plantations
# União das freguesias de Santa Vitória e Mombeja		1475.60		1813.00		Citrus plantations
# União das freguesias de Grândola e Santa Margarida da Serra		1573.10		1660.00		Citrus plantations
# União das freguesias de Serpa (Salvador e Santa Maria)		1255.30		1616.67		Citrus plantations
# Figueira dos Cavaleiros		1592.40		1604.00		Citrus plantations
# Pias		1533.70		1516.67		Citrus plantations
#
# Top 10 Regions with Slowest Changes in Variation:
# ----------------------------------------------
# Region Name		Slope		Variation	Crop Name
# ----------------------------------------------
# Quinta do Conde		0.00		0.00		Citrus plantations
# Silvalde		0.00		0.00		Citrus plantations
# São Domingos de Benfica		0.00		0.00		Citrus plantations
# São Jacinto		0.00		0.00		Citrus plantations
# União das freguesias de Agualva e Mira-Sintra		0.00		0.00		Citrus plantations
# União das freguesias de Aldoar, Foz do Douro e Nevogilde		0.00		0.00		Citrus plantations
# União das freguesias de Cedofeita, Santo Ildefonso, Sé, Miragaia, São Nicolau e Vitória		0.00		0.00		Citrus plantations
# União das freguesias de Glória e Vera Cruz		0.00		0.00		Citrus plantations
# União das freguesias de Massamá e Monte Abraão		0.00		0.00		Citrus plantations
# União das freguesias do Cacém e São Marcos		0.00		0.00		Citrus plantations

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the data from a CSV file
data = pd.read_csv('3_perm_crops.csv')

# Step 2: Calculate the sum of the area for each region and crop
sum_area = data.groupby(['region_name', 'Perm_crop'])[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Calculate the slope and variation for each region and crop
region_crop_stats = []
for (region, crop), region_crop_data in sum_area.groupby(['region_name', 'Perm_crop']):
    years = ['1989', '1999', '2009', '2019']
    x = np.arange(len(years))
    y = region_crop_data.values.squeeze()
    coeffs = np.polyfit(x, y, 1)
    slope = coeffs[0]
    variation = np.abs(np.diff(y)).mean()
    region_crop_stats.append((region, crop, slope, variation))

# Separate region-crop combinations into positive slopes and negative slopes
positive_slopes = [(region, crop, slope, variation) for region, crop, slope, variation in region_crop_stats if slope > 0]
negative_slopes = [(region, crop, slope, variation) for region, crop, slope, variation in region_crop_stats if slope < 0]

# Sort the positive and negative slopes based on slope value in descending order
sorted_positive_slopes = sorted(positive_slopes, key=lambda x: x[2], reverse=True)
sorted_negative_slopes = sorted(negative_slopes, key=lambda x: abs(x[2]), reverse=True)

# Display the top 10 region-crop combinations with the biggest positive slopes
print('Top 10 Region-Crop Combinations with Biggest Positive Slopes:')
print('----------------------------------------------------------')
print('Region Name\t\tCrop Name\t\tSlope\t\tVariation')
print('----------------------------------------------------------')
for region_crop in sorted_positive_slopes[:10]:
    print(f"{region_crop[0]}\t\t{region_crop[1]}\t\t{region_crop[2]:.2f}\t\t{region_crop[3]:.2f}")
print()

# Display the top 10 region-crop combinations with the biggest negative slopes
print('Top 10 Region-Crop Combinations with Biggest Negative Slopes:')
print('----------------------------------------------------------')
print('Region Name\t\tCrop Name\t\tSlope\t\tVariation')
print('----------------------------------------------------------')
for region_crop in sorted_negative_slopes[:10]:
    print(f"{region_crop[0]}\t\t{region_crop[1]}\t\t{region_crop[2]:.2f}\t\t{region_crop[3]:.2f}")
print()

# Create a table using pandas.DataFrame.style for positive slopes
positive_slopes_df = pd.DataFrame(sorted_positive_slopes, columns=['Region Name', 'Crop Name', 'Slope', 'Variation'])
top_10_positive_slopes = positive_slopes_df.head(10)
positive_styled_table = top_10_positive_slopes.style.set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'center')]}]
).set_caption('Top 10 Region-Crop Combinations with Biggest Positive Slopes')

# Convert styled table to DataFrame for positive slopes
positive_table_df = positive_styled_table.data

# Display the table for positive slopes using matplotlib.pyplot.table
plt.figure(figsize=(8, 4))
plt.axis('off')
plt.title('Top 10 Region-Crop Combinations with Biggest Positive Slopes')
table = plt.table(cellText=positive_table_df.values,
                  colLabels=positive_table_df.columns,
                  cellLoc='center',
                  loc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1, 1.2)
plt.show()

# Create a table using pandas.DataFrame.style for negative slopes
negative_slopes_df = pd.DataFrame(sorted_negative_slopes, columns=['Region Name', 'Crop Name', 'Slope', 'Variation'])
top_10_negative_slopes = negative_slopes_df.head(10)
negative_styled_table = top_10_negative_slopes.style.set_table_styles(
    [{'selector': 'th', 'props': [('text-align', 'center')]}]
).set_caption('Top 10 Region-Crop Combinations with Biggest Negative Slopes')

# Convert styled table to DataFrame for negative slopes
negative_table_df = negative_styled_table.data

# Display the table for negative slopes using matplotlib.pyplot.table
plt.figure(figsize=(8, 4))
plt.axis('off')
plt.title('Top 10 Region-Crop Combinations with Biggest Negative Slopes')
table = plt.table(cellText=negative_table_df.values,
                  colLabels=negative_table_df.columns,
                  cellLoc='center',
                  loc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1, 1.2)
plt.show()

# Create a graph showing region-crop combinations and their variations for positive slopes
plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_positive_slopes, x='Region Name', y='Variation', hue='Crop Name')
plt.xlabel('Region Name')
plt.ylabel('Variation')
plt.title('Region-Crop Combinations with the Biggest Variations (Positive Slopes)')
plt.xticks(rotation=90, ha='center')
plt.legend(title='Crop Name')
plt.tight_layout()
plt.show()

# Create a graph showing region-crop combinations and their variations for negative slopes
plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_negative_slopes, x='Region Name', y='Variation', hue='Crop Name')
plt.xlabel('Region Name')
plt.ylabel('Variation')
plt.title('Region-Crop Combinations with the Biggest Variations (Negative Slopes)')
plt.xticks(rotation=90, ha='center')
plt.legend(title='Crop Name')
plt.tight_layout()
plt.show()
# Out:
# Top 10 Region-Crop Combinations with Biggest Positive Slopes:
# ----------------------------------------------------------
# Region Name		Crop Name		Slope		Variation
# ----------------------------------------------------------
# União das freguesias de Alcácer do Sal (Santa Maria do Castelo e Santiago) e Santa Susana		Nuts plantations		4531.80		3846.33
# União das freguesias de Ferreira do Alentejo e Canhestros		Olive plantations		2203.20		2116.00
# Comporta		Nuts plantations		1844.80		2049.67
# Baleizão		Olive plantations		1839.00		1634.33
# União das freguesias de Grândola e Santa Margarida da Serra		Nuts plantations		1761.30		1592.33
# União das freguesias de São Miguel do Pinheiro, São Pedro de Solis e São Sebastião dos Carros		Nuts plantations		1487.70		1891.33
# União das freguesias de Moura (Santo Agostinho e São João Baptista) e Santo Amador		Olive plantations		1258.40		1302.67
# União das freguesias de Coruche, Fajarda e Erra		Nuts plantations		1211.20		1230.33
# Pias		Olive plantations		1197.30		1138.67
# Figueira dos Cavaleiros		Olive plantations		1190.60		1175.00
#
# Top 10 Region-Crop Combinations with Biggest Negative Slopes:
# ----------------------------------------------------------
# Region Name		Crop Name		Slope		Variation
# ----------------------------------------------------------
# Castelo Branco		Olive plantations		-882.20		902.33
# Alpiarça		Vineyards		-589.50		581.00
# Santa Maria, São Pedro e Sobral da Lagoa		Fresh fruit plantations (excluding citrus plantations)		-502.10		647.67
# União das freguesias de São Facundo e Vale das Mós		Olive plantations		-456.90		460.67
# Palmela		Vineyards		-446.10		485.00
# União das freguesias de Escalos de Baixo e Mata		Olive plantations		-443.40		520.33
# União das freguesias de Gavião e Atalaia		Olive plantations		-378.40		454.33
# União das freguesias de Manique do Intendente, Vila Nova de São Pedro e Maçussa		Vineyards		-374.20		375.00
# Alcanede		Olive plantations		-337.90		338.33
# Fazendas de Almeirim		Vineyards		-337.70		353.33
# C:\Users\alfor\AppData\Local\Temp\ipykernel_10492\3114831212.py:103: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
# C:\Users\alfor\AppData\Local\Temp\ipykernel_10492\3114831212.py:114: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from a CSV file
data = pd.read_csv('3_perm_crops.csv')

# Step 2: Calculate the sum of the area for each region
sum_area = data.groupby('region_name')[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum()

# Step 3: Categorize the regions based on slope
years = ['1989', '1999', '2009', '2019']
regions = sum_area.index

positive_slope_regions = []
negative_slope_regions = []
in_between_regions = []

for region in regions:
    # Calculate the trend line using linear regression
    x = range(len(years))
    y = sum_area.loc[region].values
    coeffs = np.polyfit(x, y, 1)
    slope = coeffs[0]

    if slope > 1.5:
        positive_slope_regions.append(region)
    elif slope < -1.5:
        negative_slope_regions.append(region)
    else:
        in_between_regions.append(region)

# Count the number of regions in each category
positive_count = len(positive_slope_regions)
negative_count = len(negative_slope_regions)
in_between_count = len(in_between_regions)

# Create a pie chart
categories = ['Positive Slope', 'Negative Slope', 'In Between']
counts = [positive_count, negative_count, in_between_count]

plt.pie(counts, labels=categories, autopct='%1.1f%%')

# Add count numbers below the percentages
plt.gca().set_aspect('equal')  # Ensure pie is drawn as a circle
plt.text(0.25, 0.35, f'{positive_count}', fontsize=9)
plt.text(-0.6, -0.45, f'{negative_count}', fontsize=9)
plt.text(0.45, -0.35, f'{in_between_count}', fontsize=9)

plt.title('Distribution of Slope Categories')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from a CSV file
data = pd.read_csv('3_perm_crops.csv')

# Filter data for Citrus plantations
Citrus_data = data[data['Perm_crop'] == 'Citrus plantations']

# Calculate the sum of all four years for each region
Citrus_data['Total_Area'] = Citrus_data[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum(axis=1)

# Filter regions with area of 1 or less
Citrus_data = Citrus_data[Citrus_data['Total_Area'] > 20]

# Sort the values by the total area in descending order
Citrus_data = Citrus_data.sort_values(by='Total_Area', ascending=False)

plt.figure(figsize=(13, 8))

# Plot the bars for each year with specific colors
plt.bar(Citrus_data['region_name'], Citrus_data['Area_1989'], label='1989', color='blue')
plt.bar(Citrus_data['region_name'], Citrus_data['Area_1999'], label='1999', color='orange')
plt.bar(Citrus_data['region_name'], Citrus_data['Area_2009'], label='2009', color='green')
plt.bar(Citrus_data['region_name'], Citrus_data['Area_2019'], label='2019', color='red')

plt.title('Citrus Cultivation Over Time')
plt.xlabel('Nuts Region')
plt.ylabel('Area (hectares)')

# Remove x-axis labels
plt.xticks([])

# Set y-axis limits
plt.ylim(0, 3000)

# Create legends with colors for each year
legend_colors = ['blue', 'orange', 'green', 'red']
legend_labels = ['1989', '1999', '2009', '2019']
plt.legend(legend_labels, loc='upper right', title='Year', facecolor='white')

plt.show()
# Out:
# C:\Users\alfor\AppData\Local\Temp\ipykernel_26576\4131635390.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Citrus_data['Total_Area'] = Citrus_data[['Area_1989', 'Area_1999', 'Area_2009', 'Area_2019']].sum(axis=1)
